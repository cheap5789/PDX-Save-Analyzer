# %% [markdown]
# # Find Key
#
# Search for any key anywhere in the EU5 save JSON tree. Substring search by default, with optional exact match. Prints the full dot-path and value for each match.

# %%
# Setup
import sys, os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
os.chdir(PROJECT_ROOT)
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: c:\Users\PH\Documents\Claude\Projects\PDX Save Analyzer

# %%
# === CONFIGURATION ===
SAVE_FILE   = "saves/autosave.eu5"
RAKALY_BIN  = "bin/rakaly/rakaly"

# %%
from toolbox.save_loader import load_save
from toolbox.find_key import _search, _format_value

save = load_save(SAVE_FILE, rakaly_bin=RAKALY_BIN, verbose=True)
data = save.raw
print("Save loaded.")
# Out:
# [save_loader] Parsing autosave.eu5 via rakaly...
# Save loaded.
# [save_loader] Parsed OK.

# %% [markdown]
# ## Search
#
# Edit `SEARCH_TERM`, `EXACT`, and `MAX_RESULTS` and re-run the cell.

# %%
# === SEARCH PARAMETERS ===
SEARCH_TERM = "treasury"       # What to search for
EXACT       = False             # True = exact key match, False = substring
MAX_RESULTS = 50                # Stop after this many hits

count = 0
for path, val in _search(data, SEARCH_TERM, EXACT, []):
    print(f"  {path}")
    print(f"    = {_format_value(val)}")
    count += 1
    if count >= MAX_RESULTS:
        print(f"\n... stopped at {MAX_RESULTS} results.")
        break

if count == 0:
    print(f"No keys matching {SEARCH_TERM!r} found.")
else:
    print(f"\n{count} result(s) found.")
# Out:
#   countries.database.3.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 1
#   countries.database.3.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 2
#   countries.database.4.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 2
#   countries.database.4.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 3
#   countries.database.5.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 3
#   countries.database.5.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 4
#   countries.database.6.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 4
#   countries.database.6.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 5
#   countries.database.8.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 9
#   countries.database.8.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 10
#   countries.database.9.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 10
#   countries.database.9.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 11
#   countries.database.10.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 11
#   countries.database.10.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 12
#   countries.database.11.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 12
#   countries.database.11.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 1
#   countries.database.12.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 10
#   countries.database.12.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 11
#   countries.database.13.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 11
#   countries.database.13.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 12
#   countries.database.14.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 3
#   countries.database.14.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 4
#   countries.database.15.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 4
#   countries.database.15.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 5
#   countries.database.16.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 5
#   countries.database.16.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 6
#   countries.database.17.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 6
#   countries.database.17.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 7
#   countries.database.18.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 7
#   countries.database.18.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 8
#   countries.database.19.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 8
#   countries.database.19.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 9
#   countries.database.20.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 9
#   countries.database.20.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 10
#   countries.database.21.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 10
#   countries.database.21.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 11
#   countries.database.22.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 9
#   countries.database.22.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 10
#   countries.database.23.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 12
#   countries.database.23.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 1
#   countries.database.24.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 1
#   countries.database.24.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 2
#   countries.database.25.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 2
#   countries.database.25.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 3
#   countries.database.26.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 3
#   countries.database.26.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 4
#   countries.database.27.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 4
#   countries.database.27.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 5
#   countries.database.28.ai_memory.generic_action_cooldowns.action_cd.contribute_to_organization_treasury
#     = 5
#   countries.database.28.ai_memory.generic_action_cooldowns.action_cd.withdraw_from_organization_treasury
#     = 6
#
# ... stopped at 50 results.
#
# 50 result(s) found.

# %% [markdown]
# ## Quick Searches
#
# Run multiple searches in one go. Add terms to the list below.

# %%
TERMS = ["gold", "manpower", "stability", "war_exhaustion", "prestige"]

for term in TERMS:
    results = list(_search(data, term, exact=True, path=[]))
    print(f"\n{'='*60}")
    print(f"  {term!r} — {len(results)} result(s)")
    print(f"{'='*60}")
    for path, val in results[:5]:
        print(f"  {path}")
        print(f"    = {_format_value(val)}")
# Out:
# ============================================================
#   'gold' — 12390 result(s)
# ============================================================
#   construction_manager.database.2164260867.actual_currency_spent.gold
#     = 33.64471
#   construction_manager.database.2801795079.actual_currency_spent.gold
#     = 33.53
#   construction_manager.database.3422552073.actual_currency_spent.gold
#     = 33.97504
#   construction_manager.database.2969567246.actual_currency_spent.gold
#     = 33.26014
#   construction_manager.database.2852126737.actual_currency_spent.gold
#     = 32.98134
#
# ============================================================
#   'manpower' — 653 result(s)
# ============================================================
#   construction_manager.database.2214592701.actual_currency_spent.manpower
#     = 0.2
#   construction_manager.database.3070230758.actual_currency_spent.manpower
#     = 1
#   construction_manager.database.2315256046.actual_currency_spent.manpower
#     = 0.25
#   construction_manager.database.2281701681.actual_currency_spent.manpower
#     = 0.2
#   construction_manager.database.2583691629.actual_currency_spent.manpower
#     = 1
#
# ============================================================
#   'stability' — 2448 result(s)
# ============================================================
#   countries.database.0.currency_data.stability
#     = 0.00606
#   countries.database.1.currency_data.stability
#     = 0.00606
#   countries.database.2.currency_data.stability
#     = 0.00606
#   countries.database.3.currency_data.stability
#     = 30.47656
#   countries.database.4.currency_data.stability
#     = 8.70979
#
# ============================================================
#   'war_exhaustion' — 720 result(s)
# ============================================================
#   countries.database.0.currency_data.war_exhaustion
#     = -43.275
#   countries.database.1.currency_data.war_exhaustion
#     = -43.275
#   countries.database.2.currency_data.war_exhaustion
#     = -43.275
#   countries.database.4.currency_data.war_exhaustion
#     = 5.44328
#   countries.database.16.currency_data.war_exhaustion
#     = 0.36644
#
# ============================================================
#   'prestige' — 2363 result(s)
# ============================================================
#   countries.database.3.currency_data.prestige
#     = 23.62734
#   countries.database.4.currency_data.prestige
#     = 32.45524
#   countries.database.5.currency_data.prestige
#     = 14.17318
#   countries.database.6.currency_data.prestige
#     = 21.33116
#   countries.database.7.currency_data.prestige
#     = 20

# %% [markdown]
# ## Collect Results Programmatically

# %%
# Collect all matches for a key into a list for further processing
results = [(path, val) for path, val in _search(data, "gold", exact=True, path=[])]
print(f"Found {len(results)} matches for 'gold' (exact)")

# Example: extract all gold values from country currency_data
gold_values = [
    (path, val) for path, val in results
    if "currency_data" in path and isinstance(val, (int, float))
]
print(f"Of which {len(gold_values)} are in currency_data")
for path, val in gold_values[:10]:
    print(f"  {path}: {val}")
# Out:
# Found 12390 matches for 'gold' (exact)
# Of which 3289 are in currency_data
#   countries.database.0.currency_data.gold: 10
#   countries.database.1.currency_data.gold: 10.00242
#   countries.database.2.currency_data.gold: 134617.33154
#   countries.database.3.currency_data.gold: 708.21738
#   countries.database.4.currency_data.gold: 0.15655
#   countries.database.5.currency_data.gold: 270.46342
#   countries.database.6.currency_data.gold: 160.04163
#   countries.database.7.currency_data.gold: 10
#   countries.database.8.currency_data.gold: 10
#   countries.database.9.currency_data.gold: 5
